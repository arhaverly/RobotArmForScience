# %%
from plotting.plotter import Plotter
pt = Plotter('DFFC_PdPtCu', [[0, 300]])
# Out:
# Database DFFC_PdPtCu connected successfully!
# Table recipe already exists on server, checking column consistency...
# Table recipe column consistency checked successfully!
# Table sample already exists on server, checking column consistency...
# Table sample column consistency checked successfully!
# Table performance already exists on server, checking column consistency...
# Table performance column consistency checked successfully!

# %%
pt.plot('20230422 sample batch 1-6')

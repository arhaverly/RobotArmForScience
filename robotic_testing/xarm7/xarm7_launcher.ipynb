# %% [markdown]
# # Main program

# %%
from robotic_testing.xarm7.xarm7_main import xarm7_RobotTest
# exp_name = 'temp'
# exp_name = 'default'
exp_name = 'DFFC_8D_4'
# exp_name = 'DFFC_PdPtCu'
# exp_name = 'default' # for honda
rt = xarm7_RobotTest(exp_name=exp_name)
# Out:
# SDK_VERSION: 1.8.4
# FIRMWARE_VERSION: v1.10.0, PROTOCOL: V1, DETAIL: 7,7,XS1203,AC1300,v1.10.0
# [2023-10-12 18:06:40][23] xArm-Python-SDK Version:1.8.4
# [motion_enable], xArm is not ready to move
# [set_state], xArm is ready to move

# %%
# For DFFC
for i in range(1):
    run_config = {
        'sequence': True,
        'sample_id_list': [81, 100],
        'sample_rack_id_starting': 0,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For DFFC
for i in range(1):
    run_config = {
        'sequence': True,
        'sample_id_list': [110, 113],
        'sample_rack_id_starting': 3,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For DFFC
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': [84],
        'sample_rack_id_starting': 3,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For DFFC
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': [89],
        'sample_rack_id_starting': 8,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For DFFC
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': ['4d-tem'],
        'sample_rack_id_starting': 25,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': False,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For DFFC
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': ['pure_Pd_redrop-2','3D_champion_redrop-2'],
        'sample_rack_id_starting': 7,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': False,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For Honda
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': ['47a', '48a', '49a', '50a', '51a', '52a', '53a', '54a', '47b', '48b', '49b', '50b', '51b', '52b', '53b', '54b', '47c', '48c', '49c', '50c', '51c', '52c', '53c', '54c'],
        'sample_rack_id_starting': 0,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': False,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
# For Honda
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': ['33b', '34b', '35b', '36b', '37b', '38b', '39b', '40b', '41b', '42b', '43b', '44b', '45b', '46b'],
        'sample_rack_id_starting': 14,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': False,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)
# Out:
# 2023-09-22 09:31:58 [yagmail] [ERROR] : Connection unexpectedly closed: The read operation timed out
# 2023-09-22 09:32:01 [yagmail] [ERROR] : please run connect() first
# 2023-09-22 09:32:07 [yagmail] [ERROR] : please run connect() first

# %%
# For Honda
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': ['33c', '34c', '35c', '36c', '37c', '38c', '39c', '40c'],
        'sample_rack_id_starting': 28,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': False,
        'operator_name': 'zhen',
    }
    rt.run(**run_config)

# %%
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': ['mix'],
        'sample_rack_id_starting': 0,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': False,
    }
    rt.run(**run_config)

# %%
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': [505],
        'sample_rack_id_starting': 22,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
    }
    rt.run(**run_config)

# %%
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': [509],
        'sample_rack_id_starting': 26,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
    }
    rt.run(**run_config)

# %%
for i in range(1):
    run_config = {
        'sequence': False,
        'sample_id_list': [502],
        'sample_rack_id_starting': 19,
        'immerse_option': 'flask_contact_immersed',
        'data_analysis': True,
    }
    rt.run(**run_config)

# %%
sample_id_list = [5, 8, 11, 12, 18, 19, 20, 22, 26, 29, 30, 34]
for i in sample_id_list:
    run_config = {
        'sequence': False,
        'sample_id_list': [i],
        'sample_rack_id_starting': i - 1,
        'data_analysis': False,
    }
    rt.run(**run_config)

# %% [markdown]
# 14_11-31-3

# %%
res = rt.analyze_test_results('84', 'DFFC_8D_4_sample#84_2023-10-17_14-40-10', 1)

# %%
rt.db.add_data_to_server(rt.db.configs['tables_dict']['active_learning.performance'], res)

# %% [markdown]
# # Robotic arm control

# %%
rt.arm.home()

# %%
rt.arm.move_to_mid_station()

# %%
rt.arm.load_sample(35, immerse_option='flask_contact_not_immersed')

# %%
rt.arm.unload_sample(13)

# %%
rt.arm.pick_up_sample(35)

# %%
rt.arm.put_sample_back(12)

# %%
rt.arm.pick_up_sample(11, correction=True)

# %%
rt.arm.move_to_flask()

# %%
rt.arm.sink_in_flask()

# %%
rt.arm.sink_in_flask(reverse=True)

# %%
rt.arm.rinsing()

# %%
rt.arm.close_gripper()

# %%
rt.arm.open_gripper()

# %%
rt.arm.keep_robot_alive()

# %% [markdown]
# # Software control

# %%
rt.sw.clear_recording_folder()

# %%
rt.data_analysis(
    # test_name='bh_oer_#0_2022-10-18_18-03-57',
    # save_raw_data=False
)

# %%
rt.sw.open_software()
rt.sw.click_button('icons/experiment.png')

# %% [markdown]
# # Scratch

# %%
for i in range(6):
    rt.arm.load_sample(i)
    rt.arm.unload_sample(i)

# %%
for i in [0, 5]:
    rt.arm.pick_up_sample(i)
    # rt.arm.rinsing()
    rt.arm.put_back_sample(i)

# %%
run_config = {
    'sequence': False,
    'sample_id_list': [
        # 121, 122, 123, 124, 231, 232, 233, 234, 321, 322, 323, 324,
                       331, 332, 333, 334, 351, 352, 353, 354
                       ],
    'sample_starting_pos': 0,
    'data_analysis': False,
}
for i in range(1):
    rt.run(**run_config)
